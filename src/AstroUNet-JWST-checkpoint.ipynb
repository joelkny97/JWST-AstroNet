# %%
# !pip install torch torchvision

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AstroUNet(nn.Module):
    def __init__(self, exp_injection=True):
        super().__init__()
        self.exp_injection = exp_injection

        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.LeakyReLU(0.2),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.LeakyReLU(0.2)
            )

        self.enc1 = conv_block(1, 32)
        self.enc2 = conv_block(32, 64)
        self.enc3 = conv_block(64, 128)
        self.enc4 = conv_block(128, 256)
        self.enc5 = conv_block(256, 512)

        self.pool = nn.MaxPool2d(2)

        self.dec6 = conv_block(512 + 256 + (1 if exp_injection else 0), 256)
        self.dec7 = conv_block(256 + 128, 128)
        self.dec8 = conv_block(128 + 64, 64)
        self.dec9 = conv_block(64 + 32, 32)

        self.final = nn.Conv2d(32, 1, kernel_size=1)

    def center_crop(self, enc_feat, target):
        _, _, h, w = enc_feat.size()
        _, _, th, tw = target.size()
        dh, dw = h - th, w - tw
        cropped = enc_feat[:, :, dh//2:h - (dh - dh//2), dw//2:w - (dw - dw//2)]
        return cropped

    def forward(self, x, exp_time=None):
        e = None
        if self.exp_injection and exp_time is not None:
            e = torch.full_like(x[:, :1], exp_time)

        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        e5 = self.enc5(self.pool(e4))

        # Decoder with interpolation + safe crop
        d6 = F.interpolate(e5, scale_factor=2, mode='bilinear', align_corners=False)
        e4_c = self.center_crop(e4, d6)
        if self.exp_injection:
            e_crop = self.center_crop(e, d6)
            d6 = torch.cat([d6, e4_c, e_crop], dim=1)
        else:
            d6 = torch.cat([d6, e4_c], dim=1)
        d6 = self.dec6(d6)

        d7 = F.interpolate(d6, scale_factor=2, mode='bilinear', align_corners=False)
        e3_c = self.center_crop(e3, d7)
        d7 = torch.cat([d7, e3_c], dim=1)
        d7 = self.dec7(d7)

        d8 = F.interpolate(d7, scale_factor=2, mode='bilinear', align_corners=False)
        e2_c = self.center_crop(e2, d8)
        d8 = torch.cat([d8, e2_c], dim=1)
        d8 = self.dec8(d8)

        d9 = F.interpolate(d8, scale_factor=2, mode='bilinear', align_corners=False)
        e1_c = self.center_crop(e1, d9)
        d9 = torch.cat([d9, e1_c], dim=1)
        d9 = self.dec9(d9)

        return self.final(d9)

# %%
from astropy.io import fits
import numpy as np

def load_jwst_i2d_image(fits_path):
    with fits.open(fits_path) as hdul:
        image = hdul['SCI'].data  # 2D science image
        header = hdul['SCI'].header
        image = np.nan_to_num(image)
        
        # Normalize (1%–99% clipping)
        vmin, vmax = np.percentile(image, [1, 99])
        norm_image = np.clip((image - vmin) / (vmax - vmin), 0, 1).astype(np.float32)
        
        # Exposure time
        exp_time = header.get("EXPTIME", 1000.0)
        
    return norm_image, exp_time

# %%
def extract_patches(image, patch_size=256, stride=256, max_patches=100):
    patches = []
    H, W = image.shape
    for i in range(0, H - patch_size + 1, stride):
        for j in range(0, W - patch_size + 1, stride):
            patch = image[i:i+patch_size, j:j+patch_size]
            if np.mean(patch) > 0.01:  # Skip blank
                patches.append(patch)
            if len(patches) >= max_patches:
                return patches
    return patches

# %%
def simulate_noise(image, exp_time, ratio=2, ron=3, dark_current=7):
    """
    image: normalized [0, 1], assume units = e-/sec
    exp_time: in seconds
    """
    img_e = image * exp_time  # Convert to electrons

    signal = np.random.poisson(img_e / ratio)
    read_noise = np.random.normal(0, ron, image.shape)
    dark_noise = np.random.normal(0, np.sqrt(dark_current * exp_time / (3600 * ratio)), image.shape)

    noisy_e = signal + read_noise + dark_noise
    noisy_image = noisy_e / (exp_time / ratio)

    noisy_image = np.clip(noisy_image, 0, None)
    return noisy_image.astype(np.float32)

# %%
import torch
import os

def generate_training_pairs(image, exp_time, save_dir, prefix, patch_size=256, stride=256):
    os.makedirs(save_dir, exist_ok=True)
    clean_patches = extract_patches(image, patch_size, stride)
    saved_paths = []

    for idx, clean in enumerate(clean_patches):
        noisy = simulate_noise(clean, exp_time)
        clean_tensor = torch.from_numpy(clean).unsqueeze(0)  # [1, H, W]
        noisy_tensor = torch.from_numpy(noisy).unsqueeze(0)
        
        noisy_path = os.path.join(save_dir, f"{prefix}_noisy_{idx:03d}.pt")
        clean_path = os.path.join(save_dir, f"{prefix}_clean_{idx:03d}.pt")

        torch.save(noisy_tensor, noisy_path)
        torch.save(clean_tensor, clean_path)

        saved_paths.append((noisy_path, clean_path))
    
    return saved_paths

# %%
import torch
from torch.utils.data import Dataset
import os

class JWSTAstroDataset(Dataset):
    def __init__(self, txt_file, root_dir="./astronet_training/", transform=None):
        """
        Args:
            txt_file (str): Path to .txt file with image pair names (noisy and clean).
            root_dir (str): Directory with .pt files.
            transform (callable, optional): Optional transform to be applied.
        """
        with open(txt_file, 'r') as f:
            self.file_list = [line.strip() for line in f.readlines()]
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        noisy_file, clean_file = self.file_list[idx].split()
        noisy = torch.load(os.path.join( noisy_file))
        clean = torch.load(os.path.join( clean_file))
        if self.transform:
            noisy = self.transform(noisy)
            clean = self.transform(clean)
        return noisy, clean

# %%
from astroquery.mast import Observations
import os

# Broader JWST filters to try
# === Filters and settings ===
jwst_filters = ["F115W", "F470N", "F480M", "F150W2", "F444W", "F162M", "F360M", "F405N", "F212N", "F182M"]
max_files_per_filter = 5
base_dir = "data"
patch_output_base = "astronet_training"


for filt in jwst_filters:
    print(f"\n🔍 Searching JWST I2D data for filter: {filt}")
    output_dir = os.path.join(base_dir, filt)
    os.makedirs(output_dir, exist_ok=True)

    obs_table = Observations.query_criteria(
        obs_collection="JWST",
        instrument_name="NIRCAM/IMAGE",
        dataproduct_type="image",
        filters=[filt],
        proposal_id=4147,
        calib_level=3
    )

    if len(obs_table) == 0:
        print(f"⚠️ No observations found for filter {filt}")
        continue

    products = Observations.get_product_list(obs_table)
    i2d_products = Observations.filter_products(
        products,
        productSubGroupDescription="I2D",
        extension="fits"
    )

    if len(i2d_products) == 0:
        print(f"⚠️ No I2D products found for filter {filt}")
        continue

    i2d_products = i2d_products[:max_files_per_filter]
    manifest = Observations.download_products(i2d_products, download_dir=output_dir)
    print(f"📥 Downloaded {len(manifest)} files to {output_dir}")

    # === Now process each FITS file for training patch generation ===
    for file_path in manifest["Local Path"]:
        try:

            image, exp_time = load_jwst_i2d_image(file_path)

            prefix = os.path.splitext(os.path.basename(file_path))[0]
            save_dir = os.path.join(patch_output_base, filt)
            generate_training_pairs(image, exp_time, save_dir, prefix)
            print(f"✅ Generated training pairs from {prefix}")

        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
# Out:
# 🔍 Searching JWST I2D data for filter: F115W
# INFO: Found cached file data/F115W/mastDownload/JWST/jw04147012001_08101_00001_nrcb1/jw04147012001_08101_00001_nrcb1_i2d.fits with expected size 118491840. [astroquery.query]
# INFO: Found cached file data/F115W/mastDownload/JWST/jw04147012001_08101_00004_nrcb3/jw04147012001_08101_00004_nrcb3_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F115W/mastDownload/JWST/jw04147012001_08101_00004_nrcb4/jw04147012001_08101_00004_nrcb4_i2d.fits with expected size 119016000. [astroquery.query]
# INFO: Found cached file data/F115W/mastDownload/JWST/jw04147012001_08101_00005_nrca4/jw04147012001_08101_00005_nrca4_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F115W/mastDownload/JWST/jw04147012001_08101_00005_nrcb1/jw04147012001_08101_00005_nrcb1_i2d.fits with expected size 118491840. [astroquery.query]
# 📥 Downloaded 5 files to data/F115W
# ✅ Generated training pairs from jw04147012001_08101_00001_nrcb1_i2d
# ✅ Generated training pairs from jw04147012001_08101_00004_nrcb3_i2d
# ✅ Generated training pairs from jw04147012001_08101_00004_nrcb4_i2d
# ✅ Generated training pairs from jw04147012001_08101_00005_nrca4_i2d
# ✅ Generated training pairs from jw04147012001_08101_00005_nrcb1_i2d
#
# 🔍 Searching JWST I2D data for filter: F470N
# INFO: Found cached file data/F470N/mastDownload/JWST/jw04147012001_02101_00002_nrcalong/jw04147012001_02101_00002_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
#  [Done]
# WARNING: Found cached file data/F470N/mastDownload/JWST/jw04147012001_02101_00003_nrcalong/jw04147012001_02101_00003_nrcalong_i2d.fits with size 0 that is different from expected size 120225600 [astroquery.query]
# INFO: Found cached file data/F470N/mastDownload/JWST/jw04147012001_02101_00004_nrcblong/jw04147012001_02101_00004_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F470N/mastDownload/JWST/jw04147012001_02101_00005_nrcblong/jw04147012001_02101_00005_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F470N/mastDownload/JWST/jw04147012001_02101_00006_nrcalong/jw04147012001_02101_00006_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# 📥 Downloaded 5 files to data/F470N
# ✅ Generated training pairs from jw04147012001_02101_00002_nrcalong_i2d
# ❌ Error processing data/F470N/mastDownload/JWST/jw04147012001_02101_00003_nrcalong/jw04147012001_02101_00003_nrcalong_i2d.fits: Empty or corrupt FITS file
# ✅ Generated training pairs from jw04147012001_02101_00004_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_02101_00005_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_02101_00006_nrcalong_i2d
#
# 🔍 Searching JWST I2D data for filter: F480M
# INFO: Found cached file data/F480M/mastDownload/JWST/jw04147012001_06101_00002_nrcblong/jw04147012001_06101_00002_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F480M/mastDownload/JWST/jw04147012001_06101_00003_nrcalong/jw04147012001_06101_00003_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F480M/mastDownload/JWST/jw04147012001_06101_00004_nrcblong/jw04147012001_06101_00004_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F480M/mastDownload/JWST/jw04147012001_06101_00005_nrcblong/jw04147012001_06101_00005_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F480M/mastDownload/JWST/jw04147012001_06101_00006_nrcalong/jw04147012001_06101_00006_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# 📥 Downloaded 5 files to data/F480M
# ✅ Generated training pairs from jw04147012001_06101_00002_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_06101_00003_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_06101_00004_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_06101_00005_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_06101_00006_nrcalong_i2d
#
# 🔍 Searching JWST I2D data for filter: F150W2
# INFO: Found cached file data/F150W2/mastDownload/JWST/jw04147012001_04101_00001_nrca2/jw04147012001_04101_00001_nrca2_i2d.fits with expected size 118451520. [astroquery.query]
# INFO: Found cached file data/F150W2/mastDownload/JWST/jw04147012001_04101_00001_nrcb3/jw04147012001_04101_00001_nrcb3_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F150W2/mastDownload/JWST/jw04147012001_04101_00004_nrcb3/jw04147012001_04101_00004_nrcb3_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F150W2/mastDownload/JWST/jw04147012001_04101_00006_nrca1/jw04147012001_04101_00006_nrca1_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F150W2/mastDownload/JWST/jw04147012001_04101_00006_nrca4/jw04147012001_04101_00006_nrca4_i2d.fits with expected size 118673280. [astroquery.query]
# 📥 Downloaded 5 files to data/F150W2
# ✅ Generated training pairs from jw04147012001_04101_00001_nrca2_i2d
# ✅ Generated training pairs from jw04147012001_04101_00001_nrcb3_i2d
# ✅ Generated training pairs from jw04147012001_04101_00004_nrcb3_i2d
# ✅ Generated training pairs from jw04147012001_04101_00006_nrca1_i2d
# ✅ Generated training pairs from jw04147012001_04101_00006_nrca4_i2d
#
# 🔍 Searching JWST I2D data for filter: F444W
# INFO: Found cached file data/F444W/mastDownload/JWST/jw04147012001_02101_00002_nrcalong/jw04147012001_02101_00002_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F444W/mastDownload/JWST/jw04147012001_02101_00003_nrcalong/jw04147012001_02101_00003_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F444W/mastDownload/JWST/jw04147012001_02101_00004_nrcblong/jw04147012001_02101_00004_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F444W/mastDownload/JWST/jw04147012001_04101_00004_nrcblong/jw04147012001_04101_00004_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F444W/mastDownload/JWST/jw04147012001_04101_00005_nrcalong/jw04147012001_04101_00005_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# 📥 Downloaded 5 files to data/F444W
# ✅ Generated training pairs from jw04147012001_02101_00002_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_02101_00003_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_02101_00004_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00004_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00005_nrcalong_i2d
#
# 🔍 Searching JWST I2D data for filter: F162M
# INFO: Found cached file data/F162M/mastDownload/JWST/jw04147012001_04101_00001_nrca2/jw04147012001_04101_00001_nrca2_i2d.fits with expected size 118451520. [astroquery.query]
# INFO: Found cached file data/F162M/mastDownload/JWST/jw04147012001_04101_00001_nrcb3/jw04147012001_04101_00001_nrcb3_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F162M/mastDownload/JWST/jw04147012001_04101_00004_nrcb3/jw04147012001_04101_00004_nrcb3_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F162M/mastDownload/JWST/jw04147012001_04101_00006_nrca1/jw04147012001_04101_00006_nrca1_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F162M/mastDownload/JWST/jw04147012001_04101_00006_nrca4/jw04147012001_04101_00006_nrca4_i2d.fits with expected size 118673280. [astroquery.query]
# 📥 Downloaded 5 files to data/F162M
# ✅ Generated training pairs from jw04147012001_04101_00001_nrca2_i2d
# ✅ Generated training pairs from jw04147012001_04101_00001_nrcb3_i2d
# ✅ Generated training pairs from jw04147012001_04101_00004_nrcb3_i2d
# ✅ Generated training pairs from jw04147012001_04101_00006_nrca1_i2d
# ✅ Generated training pairs from jw04147012001_04101_00006_nrca4_i2d
#
# 🔍 Searching JWST I2D data for filter: F360M
# INFO: Found cached file data/F360M/mastDownload/JWST/jw04147012001_08101_00001_nrcblong/jw04147012001_08101_00001_nrcblong_i2d.fits with expected size 120286080. [astroquery.query]
# INFO: Found cached file data/F360M/mastDownload/JWST/jw04147012001_08101_00002_nrcalong/jw04147012001_08101_00002_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F360M/mastDownload/JWST/jw04147012001_08101_00003_nrcblong/jw04147012001_08101_00003_nrcblong_i2d.fits with expected size 120286080. [astroquery.query]
# INFO: Found cached file data/F360M/mastDownload/JWST/jw04147012001_08101_00005_nrcalong/jw04147012001_08101_00005_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F360M/mastDownload/JWST/jw04147012001_08101_00006_nrcalong/jw04147012001_08101_00006_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# 📥 Downloaded 5 files to data/F360M
# ✅ Generated training pairs from jw04147012001_08101_00001_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_08101_00002_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_08101_00003_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_08101_00005_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_08101_00006_nrcalong_i2d
#
# 🔍 Searching JWST I2D data for filter: F405N
# INFO: Found cached file data/F405N/mastDownload/JWST/jw04147012001_04101_00002_nrcalong/jw04147012001_04101_00002_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F405N/mastDownload/JWST/jw04147012001_04101_00002_nrcblong/jw04147012001_04101_00002_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F405N/mastDownload/JWST/jw04147012001_04101_00004_nrcblong/jw04147012001_04101_00004_nrcblong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F405N/mastDownload/JWST/jw04147012001_04101_00005_nrcalong/jw04147012001_04101_00005_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# INFO: Found cached file data/F405N/mastDownload/JWST/jw04147012001_04101_00006_nrcalong/jw04147012001_04101_00006_nrcalong_i2d.fits with expected size 120225600. [astroquery.query]
# 📥 Downloaded 5 files to data/F405N
# ✅ Generated training pairs from jw04147012001_04101_00002_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00002_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00004_nrcblong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00005_nrcalong_i2d
# ✅ Generated training pairs from jw04147012001_04101_00006_nrcalong_i2d
#
# 🔍 Searching JWST I2D data for filter: F212N
# INFO: Found cached file data/F212N/mastDownload/JWST/jw04147012001_02101_00001_nrca2/jw04147012001_02101_00001_nrca2_i2d.fits with expected size 118451520. [astroquery.query]
# INFO: Found cached file data/F212N/mastDownload/JWST/jw04147012001_02101_00001_nrca3/jw04147012001_02101_00001_nrca3_i2d.fits with expected size 119016000. [astroquery.query]
# INFO: Found cached file data/F212N/mastDownload/JWST/jw04147012001_02101_00002_nrcb1/jw04147012001_02101_00002_nrcb1_i2d.fits with expected size 118491840. [astroquery.query]
# INFO: Found cached file data/F212N/mastDownload/JWST/jw04147012001_02101_00004_nrcb2/jw04147012001_02101_00004_nrcb2_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F212N/mastDownload/JWST/jw04147012001_02101_00006_nrca2/jw04147012001_02101_00006_nrca2_i2d.fits with expected size 118451520. [astroquery.query]
# 📥 Downloaded 5 files to data/F212N
# ✅ Generated training pairs from jw04147012001_02101_00001_nrca2_i2d
# ✅ Generated training pairs from jw04147012001_02101_00001_nrca3_i2d
# ✅ Generated training pairs from jw04147012001_02101_00002_nrcb1_i2d
# ✅ Generated training pairs from jw04147012001_02101_00004_nrcb2_i2d
# ✅ Generated training pairs from jw04147012001_02101_00006_nrca2_i2d
#
# 🔍 Searching JWST I2D data for filter: F182M
# INFO: Found cached file data/F182M/mastDownload/JWST/jw04147012001_06101_00002_nrcb2/jw04147012001_06101_00002_nrcb2_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F182M/mastDownload/JWST/jw04147012001_06101_00003_nrcb1/jw04147012001_06101_00003_nrcb1_i2d.fits with expected size 118451520. [astroquery.query]
# INFO: Found cached file data/F182M/mastDownload/JWST/jw04147012001_06101_00005_nrcb2/jw04147012001_06101_00005_nrcb2_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F182M/mastDownload/JWST/jw04147012001_06101_00006_nrca4/jw04147012001_06101_00006_nrca4_i2d.fits with expected size 118673280. [astroquery.query]
# INFO: Found cached file data/F182M/mastDownload/JWST/jw04147012001_06101_00006_nrcb4/jw04147012001_06101_00006_nrcb4_i2d.fits with expected size 119016000. [astroquery.query]
# 📥 Downloaded 5 files to data/F182M
# ✅ Generated training pairs from jw04147012001_06101_00002_nrcb2_i2d
# ✅ Generated training pairs from jw04147012001_06101_00003_nrcb1_i2d
# ✅ Generated training pairs from jw04147012001_06101_00005_nrcb2_i2d
# ✅ Generated training pairs from jw04147012001_06101_00006_nrca4_i2d
# ✅ Generated training pairs from jw04147012001_06101_00006_nrcb4_i2d

# %%
import os
import random

def create_dataset_splits(save_dir="./astronet_training/", train_ratio=0.8, val_ratio=0.1):
    paired_files = []

    # Walk through all subdirectories and collect clean/noisy pairs
    for root, _, files in os.walk(save_dir):
        clean_files = [f for f in files if "clean" in f and f.endswith(".pt")]
        for clean_file in clean_files:
            noisy_file = clean_file.replace("clean", "noisy")
            noisy_path = os.path.join(root, noisy_file)
            clean_path = os.path.join(root, clean_file)

            if os.path.exists(noisy_path):
                paired_files.append((noisy_path, clean_path))

    print(f"🔍 Found {len(paired_files)} total clean/noisy pairs")

    # Shuffle and split
    random.shuffle(paired_files)
    total = len(paired_files)
    train_end = int(train_ratio * total)
    val_end = int((train_ratio + val_ratio) * total)

    splits = {
        "train.txt": paired_files[:train_end],
        "val.txt": paired_files[train_end:val_end],
        "test.txt": paired_files[val_end:]
    }

    # Write split files with full paths (or relative to save_dir if needed)
    for split_name, split_data in splits.items():
        split_path = os.path.join(save_dir, split_name)
        with open(split_path, "w") as f:
            for noisy, clean in split_data:
                f.write(f"{noisy} {clean}\n")
        print(f"✅ Saved {split_name} with {len(split_data)} pairs")

# Run it
create_dataset_splits()
# Out:
# 🔍 Found 3136 total clean/noisy pairs
# ✅ Saved train.txt with 2508 pairs
# ✅ Saved val.txt with 314 pairs
# ✅ Saved test.txt with 314 pairs

# %%
train_dataset = JWSTAstroDataset(txt_file="./astronet_training/train.txt")
val_dataset = JWSTAstroDataset(txt_file="./astronet_training/val.txt")
test_dataset = JWSTAstroDataset(txt_file="./astronet_training/test.txt")

# %%
import os
import torch
import numpy as np
import pandas as pd

def compute_dataset_stats(txt_file, root_dir=""):
    # Read the list of noisy/clean filenames
    with open(txt_file, 'r') as f:
        pairs = [line.strip().split() for line in f if line.strip()]
    stats = []
    for noisy_name, clean_name in pairs:
        noisy_path = os.path.join(root_dir, noisy_name)
        clean_path = os.path.join(root_dir, clean_name)
        noisy = torch.load(noisy_path).float().squeeze().numpy()
        clean = torch.load(clean_path).float().squeeze().numpy()
        stats.append({
            "mean_noisy": noisy.mean(),
            "std_noisy": noisy.std(),
            "zero_frac_noisy": np.mean(noisy == 0),
            "mean_clean": clean.mean(),
            "std_clean": clean.std(),
            "zero_frac_clean": np.mean(clean == 0)
        })
    df = pd.DataFrame(stats)
    summary = {
        "num_samples": len(df),
        "mean_noisy_mean": df.mean_noisy.mean(),
        "mean_noisy_std":  df.mean_noisy.std(),
        "std_noisy_mean":  df.std_noisy.mean(),
        "std_noisy_std":   df.std_noisy.std(),
        "zero_noisy_avg%": df.zero_frac_noisy.mean()*100,
        "mean_clean_mean": df.mean_clean.mean(),
        "std_clean_mean":  df.std_clean.mean(),
        "zero_clean_avg%": df.zero_frac_clean.mean()*100,
    }
    return df, summary

# Compute for each split
for split in ["train", "val", "test"]:
    txt = f"./astronet_training/{split}.txt"
    df, summary = compute_dataset_stats(txt)
    print(f"\n🔸 {split.upper()} SET")
    for k, v in summary.items():
        if isinstance(v, float):
            print(f"   {k:20s}: {v:>8.3f}")
        else:
            print(f"   {k:20s}: {v}")
# Out:
# 🔸 TRAIN SET
#    num_samples         : 2508
#    mean_noisy_mean     : 0.15851737558841705
#    mean_noisy_std      : 0.09483622014522552
#    std_noisy_mean      : 0.11847914010286331
#    std_noisy_std       : 0.028935540467500687
#    zero_noisy_avg%     :    0.727
#    mean_clean_mean     : 0.1584794968366623
#    std_clean_mean      : 0.11690482497215271
#    zero_clean_avg%     :    1.443
#
# 🔸 VAL SET
#    num_samples         : 314
#    mean_noisy_mean     : 0.1532316505908966
#    mean_noisy_std      : 0.08090933412313461
#    std_noisy_mean      : 0.1186334639787674
#    std_noisy_std       : 0.029350262135267258
#    zero_noisy_avg%     :    0.820
#    mean_clean_mean     : 0.15319213271141052
#    std_clean_mean      : 0.11711397767066956
#    zero_clean_avg%     :    1.632
#
# 🔸 TEST SET
#    num_samples         : 314
#    mean_noisy_mean     : 0.15457870066165924
#    mean_noisy_std      : 0.09027930349111557
#    std_noisy_mean      : 0.12183503806591034
#    std_noisy_std       : 0.03563870117068291
#    zero_noisy_avg%     :    0.731
#    mean_clean_mean     : 0.15454164147377014
#    std_clean_mean      : 0.12037147581577301
#    zero_clean_avg%     :    1.456

# %%
noisy_batch, clean_batch = next(iter(train_loader))
print("🧪 Verifying training data:")
print(f"   Noisy shape: {noisy_batch.shape}, dtype: {noisy_batch.dtype}")
print(f"   Clean shape: {clean_batch.shape}, dtype: {clean_batch.dtype}")
print(f"   Min/Max Noisy: {noisy_batch.min().item():.3f} / {noisy_batch.max().item():.3f}")
print(f"   Min/Max Clean: {clean_batch.min().item():.3f} / {clean_batch.max().item():.3f}")
# Out:
# 🧪 Verifying training data:
#    Noisy shape: torch.Size([8, 1, 256, 256]), dtype: torch.float32
#    Clean shape: torch.Size([8, 1, 256, 256]), dtype: torch.float32
#    Min/Max Noisy: 0.000 / 1.157
#    Min/Max Clean: 0.000 / 1.000

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import os
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim
# from astrounet_dataset import JWSTAstroDataset  # from previous step
# from astrounet_model import AstroUNet          # your converted U-Net model
import numpy as np
from datetime import datetime

# === Hyperparameters ===
BATCH_SIZE = 4
NUM_EPOCHS = 100
LEARNING_RATE = 1e-4
SAVE_DIR = "./checkpoints_astrounet/"
os.makedirs(SAVE_DIR, exist_ok=True)
EXP_VAL=2.0

start_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# === Data ===
# train_dataset = JWSTAstroDataset("astronet_training/train.txt")
# val_dataset = JWSTAstroDataset("astronet_training/val.txt")

# train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)


# Dataloaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# === Model, Loss, Optimizer ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AstroUNet(exp_injection=True).to(device)
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

best_val_psnr = 0.0

# === Training Loop ===
for epoch in range(NUM_EPOCHS):
    model.train()
    running_loss = 0.0
    for noisy, clean in train_loader:
        noisy, clean = noisy.to(device), clean.to(device)
        exp_val = torch.tensor(EXP_VAL).to(device)  # inject exposure ratio (can vary)
        output = model(noisy, exp_val)

        loss = criterion(output, clean)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}, Train Loss: {avg_loss:.4f}")

    # === Evaluation ===
    model.eval()
    psnr_vals = []
    ssim_vals = []
    with torch.no_grad():
        for noisy, clean in val_loader:
            noisy, clean = noisy.to(device), clean.to(device)
            output = model(noisy, exp_val)
            output_np = output.cpu().squeeze().numpy()
            clean_np = clean.cpu().squeeze().numpy()

            psnr_vals.append(psnr(clean_np, output_np, data_range=1.0))
            ssim_vals.append(ssim(clean_np, output_np, data_range=1.0))

    avg_psnr = np.mean(psnr_vals)
    avg_ssim = np.mean(ssim_vals)
    print(f"   🔍 Val PSNR: {avg_psnr:.2f}, SSIM: {avg_ssim:.3f}")

    # === Save best model ===
    if avg_psnr > best_val_psnr:
        best_val_psnr = avg_psnr
        torch.save(model.state_dict(), os.path.join(SAVE_DIR, f"best_model_{EXP_VAL}_{start_time}.pth"))
        print("   ✅ Saved new best model!")
# Out:
# Epoch 1/100, Train Loss: 0.0224
#    🔍 Val PSNR: 33.44, SSIM: 0.941
#    ✅ Saved new best model!
# Epoch 2/100, Train Loss: 0.0109
#    🔍 Val PSNR: 35.74, SSIM: 0.954
#    ✅ Saved new best model!
# Epoch 3/100, Train Loss: 0.0097
#    🔍 Val PSNR: 36.94, SSIM: 0.958
#    ✅ Saved new best model!
# Epoch 4/100, Train Loss: 0.0094
#    🔍 Val PSNR: 37.47, SSIM: 0.960
#    ✅ Saved new best model!
# Epoch 5/100, Train Loss: 0.0091
#    🔍 Val PSNR: 37.81, SSIM: 0.960
#    ✅ Saved new best model!
# Epoch 6/100, Train Loss: 0.0090
#    🔍 Val PSNR: 38.03, SSIM: 0.961
#    ✅ Saved new best model!
# Epoch 7/100, Train Loss: 0.0087
#    🔍 Val PSNR: 38.22, SSIM: 0.962
#    ✅ Saved new best model!
# Epoch 8/100, Train Loss: 0.0086
#    🔍 Val PSNR: 38.31, SSIM: 0.962
#    ✅ Saved new best model!
# Epoch 9/100, Train Loss: 0.0085
#    🔍 Val PSNR: 38.50, SSIM: 0.961
#    ✅ Saved new best model!
# Epoch 10/100, Train Loss: 0.0085
#    🔍 Val PSNR: 38.57, SSIM: 0.962
#    ✅ Saved new best model!
# Epoch 11/100, Train Loss: 0.0084
#    🔍 Val PSNR: 38.70, SSIM: 0.962
#    ✅ Saved new best model!
# Epoch 12/100, Train Loss: 0.0084
#    🔍 Val PSNR: 38.81, SSIM: 0.963
#    ✅ Saved new best model!
# Epoch 13/100, Train Loss: 0.0084
#    🔍 Val PSNR: 38.90, SSIM: 0.963
#    ✅ Saved new best model!
# Epoch 14/100, Train Loss: 0.0082
#    🔍 Val PSNR: 38.79, SSIM: 0.963
# Epoch 15/100, Train Loss: 0.0083
#    🔍 Val PSNR: 38.90, SSIM: 0.963
# Epoch 16/100, Train Loss: 0.0082
#    🔍 Val PSNR: 39.03, SSIM: 0.964
#    ✅ Saved new best model!
# Epoch 17/100, Train Loss: 0.0082
#    🔍 Val PSNR: 39.09, SSIM: 0.964
#    ✅ Saved new best model!
# Epoch 18/100, Train Loss: 0.0081
#    🔍 Val PSNR: 39.08, SSIM: 0.964
# Epoch 19/100, Train Loss: 0.0082
#    🔍 Val PSNR: 38.78, SSIM: 0.962
# Epoch 20/100, Train Loss: 0.0081
#    🔍 Val PSNR: 39.23, SSIM: 0.965
#    ✅ Saved new best model!
# Epoch 21/100, Train Loss: 0.0080
#    🔍 Val PSNR: 39.26, SSIM: 0.965
#    ✅ Saved new best model!
# Epoch 22/100, Train Loss: 0.0080
#    🔍 Val PSNR: 39.30, SSIM: 0.965
#    ✅ Saved new best model!
# Epoch 23/100, Train Loss: 0.0080
#    🔍 Val PSNR: 39.32, SSIM: 0.965
#    ✅ Saved new best model!
# Epoch 24/100, Train Loss: 0.0080
#    🔍 Val PSNR: 39.38, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 25/100, Train Loss: 0.0081
#    🔍 Val PSNR: 39.39, SSIM: 0.965
#    ✅ Saved new best model!
# Epoch 26/100, Train Loss: 0.0079
#    🔍 Val PSNR: 39.41, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 27/100, Train Loss: 0.0079
#    🔍 Val PSNR: 39.41, SSIM: 0.966
# Epoch 28/100, Train Loss: 0.0079
#    🔍 Val PSNR: 39.46, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 29/100, Train Loss: 0.0079
#    🔍 Val PSNR: 39.49, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 30/100, Train Loss: 0.0080
#    🔍 Val PSNR: 39.39, SSIM: 0.965
# Epoch 31/100, Train Loss: 0.0078
#    🔍 Val PSNR: 39.53, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 32/100, Train Loss: 0.0078
#    🔍 Val PSNR: 39.50, SSIM: 0.965
# Epoch 33/100, Train Loss: 0.0078
#    🔍 Val PSNR: 39.53, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 34/100, Train Loss: 0.0078
#    🔍 Val PSNR: 39.42, SSIM: 0.965
# Epoch 35/100, Train Loss: 0.0078
#    🔍 Val PSNR: 39.58, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 36/100, Train Loss: 0.0078
#    🔍 Val PSNR: 38.97, SSIM: 0.965
# Epoch 37/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.54, SSIM: 0.966
# Epoch 38/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.60, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 39/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.66, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 40/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.66, SSIM: 0.967
# Epoch 41/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.56, SSIM: 0.965
# Epoch 42/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.63, SSIM: 0.966
# Epoch 43/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.61, SSIM: 0.966
# Epoch 44/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.77, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 45/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.80, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 46/100, Train Loss: 0.0077
#    🔍 Val PSNR: 39.13, SSIM: 0.964
# Epoch 47/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.68, SSIM: 0.966
# Epoch 48/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.81, SSIM: 0.966
#    ✅ Saved new best model!
# Epoch 49/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.85, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 50/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.86, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 51/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.81, SSIM: 0.966
# Epoch 52/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.85, SSIM: 0.967
# Epoch 53/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.84, SSIM: 0.967
# Epoch 54/100, Train Loss: 0.0076
#    🔍 Val PSNR: 39.79, SSIM: 0.967
# Epoch 55/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.84, SSIM: 0.966
# Epoch 56/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.87, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 57/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.85, SSIM: 0.967
# Epoch 58/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.86, SSIM: 0.967
# Epoch 59/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.94, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 60/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.94, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 61/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.89, SSIM: 0.967
# Epoch 62/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.47, SSIM: 0.966
# Epoch 63/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.80, SSIM: 0.967
# Epoch 64/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.85, SSIM: 0.967
# Epoch 65/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.93, SSIM: 0.967
# Epoch 66/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.98, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 67/100, Train Loss: 0.0075
#    🔍 Val PSNR: 39.98, SSIM: 0.967
# Epoch 68/100, Train Loss: 0.0074
#    🔍 Val PSNR: 40.00, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 69/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.68, SSIM: 0.967
# Epoch 70/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.74, SSIM: 0.967
# Epoch 71/100, Train Loss: 0.0073
#    🔍 Val PSNR: 39.94, SSIM: 0.967
# Epoch 72/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.01, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 73/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.97, SSIM: 0.967
# Epoch 74/100, Train Loss: 0.0073
#    🔍 Val PSNR: 39.86, SSIM: 0.967
# Epoch 75/100, Train Loss: 0.0073
#    🔍 Val PSNR: 39.94, SSIM: 0.967
# Epoch 76/100, Train Loss: 0.0074
#    🔍 Val PSNR: 39.99, SSIM: 0.967
# Epoch 77/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.00, SSIM: 0.967
# Epoch 78/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.01, SSIM: 0.967
# Epoch 79/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.04, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 80/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.03, SSIM: 0.967
# Epoch 81/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.04, SSIM: 0.967
# Epoch 82/100, Train Loss: 0.0073
#    🔍 Val PSNR: 39.96, SSIM: 0.967
# Epoch 83/100, Train Loss: 0.0073
#    🔍 Val PSNR: 39.94, SSIM: 0.967
# Epoch 84/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.04, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 85/100, Train Loss: 0.0073
#    🔍 Val PSNR: 40.05, SSIM: 0.967
#    ✅ Saved new best model!
# Epoch 86/100, Train Loss: 0.0072
#    🔍 Val PSNR: 39.91, SSIM: 0.967
# Epoch 87/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.04, SSIM: 0.967
# Epoch 88/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.00, SSIM: 0.967
# Epoch 89/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.03, SSIM: 0.967
# Epoch 90/100, Train Loss: 0.0072
#    🔍 Val PSNR: 39.85, SSIM: 0.966
# Epoch 91/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.01, SSIM: 0.967
# Epoch 92/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.04, SSIM: 0.967
# Epoch 93/100, Train Loss: 0.0072
#    🔍 Val PSNR: 39.98, SSIM: 0.967
# Epoch 94/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.04, SSIM: 0.967
# Epoch 95/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.02, SSIM: 0.967
# Epoch 96/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.03, SSIM: 0.967
# Epoch 97/100, Train Loss: 0.0071
#    🔍 Val PSNR: 40.04, SSIM: 0.967
# Epoch 98/100, Train Loss: 0.0071
#    🔍 Val PSNR: 40.00, SSIM: 0.967
# Epoch 99/100, Train Loss: 0.0072
#    🔍 Val PSNR: 40.02, SSIM: 0.967
# Epoch 100/100, Train Loss: 0.0071
#    🔍 Val PSNR: 39.87, SSIM: 0.967

# %%
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim

def show_denoising_result_with_metrics(index,noisy, output, clean):
    """
    Show denoising results and print PSNR/SSIM for both noisy and denoised outputs.
    Args:
        noisy, output, clean: numpy arrays of shape (H, W)
    """
    # Compute metrics
    psnr_noisy = psnr(clean, noisy, data_range=1.0)
    psnr_denoised = psnr(clean, output, data_range=1.0)

    ssim_noisy = ssim(clean, noisy, data_range=1.0)
    ssim_denoised = ssim(clean, output, data_range=1.0)

    # Plot
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    
    axs[0].imshow(noisy, cmap='gray')
    axs[0].set_title(f"Noisy Input\nPSNR: {psnr_noisy:.2f}, SSIM: {ssim_noisy:.3f}")

    axs[1].imshow(output, cmap='gray')
    axs[1].set_title(f"Denoised Output\nPSNR: {psnr_denoised:.2f}, SSIM: {ssim_denoised:.3f}")

    axs[2].imshow(clean, cmap='gray')
    axs[2].set_title("Ground Truth")

    for ax in axs:
        ax.axis('off')

    plt.suptitle("JWST Patch Denoising – Astro U-Net", fontsize=16)
    plt.tight_layout()
    plt.savefig(f"{SAVE_DIR}/output_patch_denoised_{index}.png")
    plt.show()

# %%
# !pip install jdaviz

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import os
from astroquery.mast import Observations
from jdaviz import Imviz

# download the data file
uri = f"mast:jwst/product/jw04147-o012_t001_nircam_clear-f115w_i2d.fits"
result = Observations.download_file(uri, base_url='https://mast.stsci.edu/api/v0.1/Download/file')
if result[0] == 'ERROR':
    raise RuntimeError('Error retrieving file: ' + result[1])

local = os.path.join(os.path.abspath('.'), uri.rsplit('/', 1)[-1])
print(local)
# load the data file and display
h = Imviz()
h.load_data(local)
h.show()
# Out:
# INFO: Found cached file jw04147-o012_t001_nircam_clear-f115w_i2d.fits with expected size 1733146560. [astroquery.query]
# /home/joel-kinny/Desktop/Workspace/Astro_U-net/code/jw04147-o012_t001_nircam_clear-f115w_i2d.fits
# <div class="jupyter-widget-checks-container">
#     <script>
#         (function () {
#             console.log("Checking for jupyter-widgets extensions")
#             const inLab = window._JUPYTERLAB !== undefined;
#             const silent = jupyter_widget_checks_silent;
#             const containers = document.getElementsByClassName('jupyter-widget-checks-container');
#             const rootEl = containers[containers.length - 1];
#             const libraries = window.jupyter_widget_checks_libraries;
#
#             function getBaseUrl() {
#                 const labConfigData = document.getElementById("jupyter-config-data");
#                 if (labConfigData) {
#                     /* lab and Voila */
#                     return JSON.parse(labConfigData.textContent).baseUrl;
#                 }
#                 let base = document.body.dataset.baseUrl || document.baseURI;
#                 return base;
#             }
#
#             function checkLibrary(extensions, library) {
#                 let installed = false;
#                 let ok = true;
#                 if (inLab) {
#                     installed = _JUPYTERLAB[library.lab] !== undefined
#                 } else {
#                     installed = extensions[library.classic] !== undefined;
#                     let enabled = extensions[library.classic] === true;
#                 }
#                 const div = document.createElement("div")
#                 if (installed) {
#                     if (!silent) {
#                         div.innerHTML = `Extension ${library.python} is installed at the server ✅`
#                         rootEl.appendChild(div)
#                     }
#                 } else {
#                     div.innerHTML = `Extension ${library.python} is <b>NOT</b> installed at the server ❌.`
#                     rootEl.appendChild(div)
#                     ok = false;
#                 }
#                 return ok;
#             }
#
#             async function check() {
#                 const url = `${getBaseUrl()}api/config/notebook`
#                 const response = (await fetch(url));
#                 const data = await response.json()
#                 const extensions = data["load_extensions"];
#                 var ok = true;
#                 let needsInstall = [];
#                 libraries.forEach((library) => {
#                     if (!checkLibrary(extensions, library)) {
#                         ok = false;
#                         needsInstall.push(library.python)
#                         console.log("Needs install", library.python)
#                     }
#                 })
#                 console.log(ok, needsInstall)
#                 if (!ok) {
#                     const div = document.createElement("div")
#                     const div2 = document.createElement("div")
#                     div.innerHTML = `Run <code>${jupyter_python_executable} -m pip install ${needsInstall.join(" ")}</code>. Refresh the page after installation.`
#                     div2.innerHTML = `Visit <a href="https://solara.dev/documentation/getting_started/troubleshoot" target="_blank">https://solara/dev/documentation/getting_started/troubleshoot</a> for more information.`
#                     rootEl.appendChild(div)
#                     rootEl.appendChild(div2)
#                 }
#             }
#             check()
#         })();
#     </script>
# </div>
# Application(config='imviz', docs_link='https://jdaviz.readthedocs.io/en/v4.2.1/imviz/index.html', events=['cal…

# %%
# === Config ===
# CHECKPOINT = SAVE_DIR / f"best_model_{EXP_VAL}_{start_time}.pth"
TEST_TXT = "astronet_training/test.txt"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EXP_RATIO = torch.tensor(2.0).to(DEVICE)  # Exposure ratio injected into model
SAVE_DIR = "inference_single/"
os.makedirs(SAVE_DIR, exist_ok=True)

# test_set = JWSTAstroDataset(txt_file="./astronet_training/test.txt")

model.eval()

# Randomly choose a sample
index = random.randint(0, len(test_dataset) - 1)
noisy_tensor, clean_tensor = test_dataset[index]

noisy_tensor = noisy_tensor.unsqueeze(0).to(DEVICE)  # add batch dim
clean_tensor = clean_tensor.unsqueeze(0).to(DEVICE)

# === Inference ===
with torch.no_grad():
    output_tensor = model(noisy_tensor, exp_time=EXP_RATIO)

# === Convert to numpy ===
noisy_np = noisy_tensor.squeeze().cpu().numpy()
output_np = output_tensor.squeeze().cpu().numpy()
clean_np = clean_tensor.squeeze().cpu().numpy()

show_denoising_result_with_metrics(index,noisy_np, output_np, clean_np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 29
#      26 output_np = output_tensor.squeeze().cpu().numpy()
#      27 clean_np = clean_tensor.squeeze().cpu().numpy()
# ---> 29 show_denoising_result_with_metrics(index,noisy_np, output_np, clean_np)
#
# NameError: name 'show_denoising_result_with_metrics' is not defined

# %%
EXP_TIME = 1000.0  # Total exposure time (same across all tests)

# === Load clean patch ===
dataset = JWSTAstroDataset("astronet_training/test.txt")
clean_tensor = dataset[0][1].unsqueeze(0).to(DEVICE)  # Shape: [1, 1, H, W]
clean_np = clean_tensor.squeeze().cpu().numpy()

# # === Noise simulation function ===
# def simulate_poisson_noise(image_np, exp_time, ratio, ron=3, dark=7):
#     img_e = image_np * exp_time
#     signal = np.random.poisson(img_e / ratio)
#     read_noise = np.random.normal(0, ron, image_np.shape)
#     dark_noise = np.random.normal(0, np.sqrt(dark * exp_time / (3600 * ratio)), image_np.shape)
#     noisy_e = signal + read_noise + dark_noise
#     noisy_image = np.clip(noisy_e / (exp_time / ratio), 0, 1)
#     return noisy_image.astype(np.float32)

# === Sweep over exposure ratios ===
ratios = np.linspace(0.5, 10.0, 100)  # 100 finely spaced values
psnr_values = []

for r in ratios:
    noisy_np = simulate_noise(clean_np, EXP_TIME, r)
    noisy_tensor = torch.from_numpy(noisy_np).unsqueeze(0).unsqueeze(0).to(DEVICE)

    with torch.no_grad():
        output_tensor = model(noisy_tensor, exp_time=torch.tensor(r).to(DEVICE))
    output_np = output_tensor.squeeze().cpu().numpy()

    psnr_val = psnr(clean_np, output_np, data_range=1.0)
    psnr_values.append(psnr_val)

# === Plot ===
plt.figure(figsize=(8, 5))
plt.plot(ratios, psnr_values, label="Denoised PSNR", linewidth=2)
plt.xlabel("Exposure Ratio (R)", fontsize=12)
plt.ylabel("PSNR (dB)", fontsize=12)
plt.title("Astro U-Net: PSNR vs Exposure Ratio", fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# Load full JWST FITS
path = "jw04147-o012_t001_nircam_clear-f115w_i2d.fits"

with fits.open(path) as hdul:
    image = hdul['SCI'].data
    image = np.nan_to_num(image)

    # Normalize for display
    vmin, vmax = np.percentile(image, [1, 99])
    norm_img = np.clip((image - vmin) / (vmax - vmin), 0, 1)

# Show
plt.figure(figsize=(12, 10))
plt.imshow(norm_img, cmap='gray', origin='lower')
plt.colorbar(label='Normalized Flux')
plt.title("Full JWST Image (SCI)")
plt.show()

# %%
# Reconstruction of whole image
def extract_image_patches(image, patch_size=256, stride=128):
    H, W = image.shape
    patches = []
    positions = []
    for i in range(0, H - patch_size + 1, stride):
        for j in range(0, W - patch_size + 1, stride):
            patch = image[i:i+patch_size, j:j+patch_size]
            patches.append(patch)
            positions.append((i, j))
    return patches, positions

def reconstruct_image(patches, positions, image_shape, patch_size=256):
    reconstructed = np.zeros(image_shape)
    weight = np.zeros(image_shape)

    for patch, (i, j) in zip(patches, positions):
        reconstructed[i:i+patch_size, j:j+patch_size] += patch
        weight[i:i+patch_size, j:j+patch_size] += 1

    return reconstructed / np.maximum(weight, 1e-8)

# %%
import torch

def denoise_full_image(image, model, exp_ratio=2.0, patch_size=256, stride=128):
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    norm_image = np.clip(image / np.percentile(image, 99), 0, 1).astype(np.float32)
    patches, positions = extract_image_patches(norm_image, patch_size, stride)
    denoised_patches = []

    for patch in patches:
        tensor = torch.from_numpy(patch).unsqueeze(0).unsqueeze(0).to(device)
        with torch.no_grad():
            out = model(tensor, exp_time=torch.tensor(exp_ratio).to(device))
        denoised_patches.append(out.squeeze().cpu().numpy())

    denoised_full = reconstruct_image(denoised_patches, positions, image.shape, patch_size)
    return denoised_full

# %%
# === Step 1: Create the model instance
model = AstroUNet(exp_injection=True)  # or False if you trained without exposure injection

# === Step 2: Load state_dict
checkpoint_path = "checkpoints_astrounet/best_model.pth"
model.load_state_dict(torch.load(checkpoint_path, map_location="cpu"))  # or "cuda"

# === Step 3: Set to evaluation mode
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()


denoised = denoise_full_image(image, model, exp_ratio=2.0)

plt.figure(figsize=(12, 10))
plt.imshow(denoised, cmap='gray', origin='lower')
plt.title("Full JWST Image (Denoised by Astro U-Net)")
plt.colorbar(label='Normalized Flux')
plt.savefig("output_full_reconstructed.png")
plt.show()

# %%
from torch.utils.data import DataLoader
import torch

def validate_dataset(dataset, zero_threshold=0.95, show_examples=False, max_examples=3):
    total = len(dataset)
    zero_count = 0
    zero_indices = []

    for idx in range(total):
        noisy, clean = dataset[idx]

        # Count nonzero pixels in clean
        nonzero = torch.count_nonzero(clean)
        total_pixels = clean.numel()
        ratio = nonzero.float() / total_pixels

        if ratio < (1 - zero_threshold):
            zero_count += 1
            zero_indices.append(idx)

            if show_examples and len(zero_indices) <= max_examples:
                import matplotlib.pyplot as plt
                plt.figure(figsize=(10, 3))
                plt.subplot(1, 2, 1)
                plt.imshow(noisy.squeeze(), cmap='gray')
                plt.title(f"Noisy Sample {idx}")
                plt.subplot(1, 2, 2)
                plt.imshow(clean.squeeze(), cmap='gray')
                plt.title(f"Clean Sample {idx} (nonzero ratio: {ratio:.2f})")
                plt.show()

    print(f"✅ Dataset has {total} samples.")
    print(f"⚠️ {zero_count} samples ({100*zero_count/total:.1f}%) are mostly zero (>{zero_threshold*100:.0f}% zeros).")
    return zero_indices

# Example with your test set
zero_patches = validate_dataset(test_dataset, zero_threshold=0.9, show_examples=True)
# Out:
# ✅ Dataset has 320 samples.
# ⚠️ 0 samples (0.0%) are mostly zero (>90% zeros).

# %% [markdown]
# # Kalman Filter added to Astro U Net

# %%
import os
import random
from datetime import datetime

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim
import wandb

# === Define your Kalman‑augmented U‑Net ===

class TorchKalmanDenoiser(nn.Module):
    def __init__(self, Q=1e-5, R=1e-2):
        super().__init__()
        self.Q = Q
        self.R = R

    def forward(self, meas: torch.Tensor, initial: torch.Tensor = None):
        meas = meas.float()
        X = initial if initial is not None else meas.clone()
        P = torch.ones_like(meas)

        P = P + self.Q
        K = P / (P + self.R)
        X = X + K * (meas - X)
        # P = (1 - K) * P  # we don't need P afterwards
        return X

class AstroKalmanUNet(nn.Module):
    def __init__(self, astrounet_model: AstroUNet=None,exp_injection=True, Q=1e-5, R=1e-2):
        super().__init__()
        # import your existing AstroUNet here
        if astrounet_model:
            self.unet   = astrounet_model
        else:
            self.unet   = AstroUNet(exp_injection=exp_injection)
        self.kalman = TorchKalmanDenoiser(Q=Q, R=R)

    def forward(self, x, exp_time=None):
        net_out   = self.unet(x, exp_time)
        filt_out  = self.kalman(net_out)
        return filt_out

# %%
# --- Hyperparameters ---
BATCH_SIZE    = 4
NUM_EPOCHS    = 50
LEARNING_RATE = 1e-4
EXP_VAL       = 2.0
EPS           = 1e-8 

start_time = datetime.now().strftime("%Y%m%d_%H%M%S")
SAVE_DIR   = f"./checkpoints_astrounet/run_{start_time}/"
os.makedirs(SAVE_DIR, exist_ok=True)

# === W&B init ===
wandb.init(
    project="astrounet-jwst",
    name=f"kalman_run_{start_time}",
    config={
        "batch_size":    BATCH_SIZE,
        "epochs":        NUM_EPOCHS,
        "lr":            LEARNING_RATE,
        "exp_injection": True,
        "exp_val":       EXP_VAL,
        "kalman_Q":      1e-5,
        "kalman_R":      1e-2
    }
)

# === Data ===
train_ds = JWSTAstroDataset(txt_file="./astronet_training/train.txt")
val_ds   = JWSTAstroDataset(txt_file="./astronet_training/val.txt")

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=1,           shuffle=False, pin_memory=True)

# === Model, Loss, Optimizer ===
device    = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model     = AstroKalmanUNet(exp_injection=True, Q=1e-5, R=1e-2).to(device)
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# === Utility for KL divergence ===
def kl_divergence(a, b, bins=100):
    """Discrete KL(P||Q) for histograms of a and b."""
    # joint bins on combined range
    mn = min(a.min(), b.min())
    mx = max(a.max(), b.max())
    P, _ = np.histogram(a, bins=bins, range=(mn, mx), density=True)
    Q, _ = np.histogram(b, bins=bins, range=(mn, mx), density=True)
    P += EPS; Q += EPS
    return np.sum(P * np.log(P / Q))


best_val_psnr = 0.0

# === Training Loop ===
for epoch in range(1, NUM_EPOCHS + 1):
    model.train()
    running_loss = 0.0

    for noisy, clean in train_loader:
        noisy, clean = noisy.to(device), clean.to(device)
        exp_tensor   = torch.tensor(EXP_VAL, device=device)

        output = model(noisy, exp_tensor)
        loss   = criterion(output, clean)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)

    # === Validation ===
    model.eval()
    metrics = {"psnr": [], "ssim": [], "snr_noisy": [], "snr_out": [],
               "kl": [], "rel_flux_err": []}

    with torch.no_grad():
        for noisy, clean in val_loader:
            noisy, clean = noisy.to(device), clean.to(device)
            output = model(noisy, exp_tensor)

            # to numpy
            n_np = noisy.cpu().squeeze().numpy()
            o_np = output.cpu().squeeze().numpy()
            c_np = clean.cpu().squeeze().numpy()

            # PSNR & SSIM
            metrics["psnr"].append(psnr(c_np, o_np, data_range=1.0))
            metrics["ssim"].append(ssim(c_np, o_np, data_range=1.0))

            # SNR: mean(signal)/std(noise)
            sig_mean = c_np.mean()
            noise_noisy = (c_np - n_np).std()
            noise_out   = (c_np - o_np).std()
            metrics["snr_noisy"].append(sig_mean / (noise_noisy + EPS))
            metrics["snr_out"].append(sig_mean / (noise_out   + EPS))

            # KL divergence
            metrics["kl"].append(kl_divergence(c_np, o_np))

            # Relative flux error
            flux_c = c_np.sum()
            flux_o = o_np.sum()
            metrics["rel_flux_err"].append(abs(flux_o - flux_c) / (flux_c + EPS))

    # average metrics
    avg = {k: np.mean(v) for k, v in metrics.items()}

    # === Log to W&B ===
    wandb.log({
        "epoch":           epoch,
        "train/loss":      avg_train_loss,
        "val/psnr":        avg["psnr"],
        "val/ssim":        avg["ssim"],
        "val/snr_noisy":   avg["snr_noisy"],
        "val/snr_out":     avg["snr_out"],
        "val/kl_div":      avg["kl"],
        "val/rel_flux_err":avg["rel_flux_err"],
        "learning_rate":   optimizer.param_groups[0]["lr"]
    })

    # === Example images every 10 epochs ===
    if epoch % 10 == 0 or epoch == 1:
        noisy, clean = next(iter(val_loader))
        noisy, clean = noisy.to(device), clean.to(device)
        output = model(noisy, exp_tensor)
        
        noisy_np  = noisy.detach().cpu().squeeze().numpy()
        output_np = output.detach().cpu().squeeze().numpy()
        clean_np  = clean.detach().cpu().squeeze().numpy()


        grid = np.stack([noisy_np, output_np, clean_np], axis=-1)

        wandb.log({"examples":
            wandb.Image(grid, caption=f"Epoch {epoch}: Noisy/Denoised/Clean")
        })

    # === Checkpointing ===
    if avg["psnr"] > best_val_psnr:
        best_val_psnr = avg["psnr"]
        ckpt_path = os.path.join(SAVE_DIR, f"best_kalman_unet_{start_time}.pth")
        torch.save(model.state_dict(), ckpt_path)
        wandb.save(ckpt_path)
        print(f"✅ Epoch {epoch}: Best PSNR={best_val_psnr:.3f}; saved {ckpt_path}")

    print(f"[{epoch}/{NUM_EPOCHS}] Train={avg_train_loss:.4f}  "
          f"PSNR={avg['psnr']:.2f}  SSIM={avg['ssim']:.3f}  "
          f"SNR↑ {avg['snr_noisy']:.2f}->{avg['snr_out']:.2f}  "
          f"KL={avg['kl']:.3f}  dF={avg['rel_flux_err']:.3f}")

# Finish
wandb.finish()

# %%
from PIL import Image
from matplotlib import pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- 2. Instantiate & load checkpoint ---
model = AstroKalmanUNet(exp_injection=True, Q=1e-5, R=1e-2).to(device)
ckpt_path = "./checkpoints_astrounet/run_20250421_174527/best_kalman_unet_20250421_174527.pth"
model.load_state_dict(torch.load(ckpt_path, map_location=device))
model.eval()

# --- 3. Prepare one sample from your test set ---
# Randomly choose a sample
index = random.randint(0, len(test_dataset) - 1)
noisy_tensor, clean_tensor = test_dataset[index]
noisy = noisy_tensor.unsqueeze(0).to(device)       # → [1,1,H,W]
clean = clean_tensor.unsqueeze(0).to(device) 
exp_time = torch.tensor(2.0, device=device) # your chosen exposure injection

# --- 4. Run inference ---
with torch.no_grad():
    denoised = model(noisy, exp_time)       # → [1,1,H,W]

# --- 5. Move back to CPU + numpy for plotting ---
noisy_np    = noisy.cpu().squeeze().numpy()
denoised_np = denoised.cpu().squeeze().numpy()
clean_np   = clean.cpu().squeeze().numpy()

show_denoising_result_with_metrics(index,noisy_np, denoised_np, clean_np)
# # --- 6. Plot side‑by‑side ---
# fig, axes = plt.subplots(1, 3, figsize=(15,5))
# for ax, img, title in zip(axes,
#                           [noisy_np, denoised_np, clean_np],
#                           ["Noisy Input", "U‑Net + Kalman", "Ground Truth"]):
#     im = ax.imshow(img, cmap="gray", origin="lower")
#     ax.set_title(title)
#     ax.axis("off")
#     fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

# plt.tight_layout()
# plt.show()
